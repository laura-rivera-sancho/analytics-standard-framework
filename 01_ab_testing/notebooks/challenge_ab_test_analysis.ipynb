# %% [markdown]
# # NovaPay Simplified Checkout A/B Test — Challenge
#
# This notebook is the **independent practice version** of the NovaPay case.
#
# You are the analyst. Your task is to move from a raw synthetic experiment dataset to a client-ready recommendation without using the guided notebook.
#
# **Business decision:** Should NovaPay roll out the simplified checkout experience?
#
# **Primary KPI:** checkout completion rate
# **Secondary KPI:** checkout time
# **Guardrails:** payment decline rate, support contact rate, fraud rate
#
# All data are synthetic and created for training and portfolio use.

# %% [markdown]
# ## How to use this challenge
#
# Work through the sections in order and document your reasoning in the markdown answer cells.
#
# Do not jump directly to significance testing. A strong experiment analysis should demonstrate:
#
# 1. Business framing
# 2. Hypothesis and decision rules
# 3. Data-quality validation
# 4. Experiment-health checks
# 5. Group balance
# 6. KPI definition
# 7. Correct statistical methods
# 8. Effect-size and confidence-interval interpretation
# 9. Guardrail assessment
# 10. Segment analysis
# 11. Business-impact translation
# 12. Final recommendation
#
# When finished, compare your approach with `guided_ab_test_analysis.ipynb`.

# %%
from pathlib import Path
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

cwd = Path.cwd()
module_root = cwd if (cwd / 'src').exists() else cwd.parent
sys.path.insert(0, str(module_root / 'src'))

from generate_synthetic_data import generate_raw_data

pd.set_option('display.max_columns', 50)
pd.set_option('display.float_format', lambda x: f'{x:,.4f}')

ALPHA = 0.05
EXPECTED_TREATMENT_SHARE = 0.50
MIN_BUSINESS_LIFT_PP = 2.0

# %% [markdown]
# ## 1. Business framing
#
# NovaPay believes its existing checkout flow creates unnecessary friction. Product proposes a simplified checkout experience.
#
# ### Your task
#
# Write a concise analytical framing covering:
#
# - What business decision must be made?
# - What is the treatment?
# - What outcome would make the treatment successful?
# - What risks could make an apparent improvement unacceptable?

# %% [markdown]
# ### Your answer
#
# > **Business decision:**
# >
# > **Treatment:**
# >
# > **Success definition:**
# >
# > **Key risks / guardrails:**

# %% [markdown]
# ## 2. Hypothesis and decision rules
#
# Before seeing experiment results, define:
#
# - Null hypothesis (H0)
# - Alternative hypothesis (H1)
# - Statistical significance threshold
# - Minimum business-relevant effect
# - What would cause you to recommend rollout, iteration, or stop

# %% [markdown]
# ### Your answer
#
# > **H0:**
# >
# > **H1:**
# >
# > **Alpha:**
# >
# > **Minimum business lift:**
# >
# > **Decision rule:**

# %% [markdown]
# ## 3. Generate and inspect the raw data
#
# The raw synthetic dataset deliberately includes realistic data-quality issues.
#
# ### Your task
#
# Generate the data, inspect its shape and columns, then identify the unit of analysis.

# %%
raw = generate_raw_data()

# TODO: inspect shape, first rows, columns, data types, and basic descriptive information

# %% [markdown]
# ### Questions
#
# - What is the experimental unit?
# - Is there one row per experimental unit?
# - What date range does the experiment cover?
# - Which variables are pre-treatment characteristics?
# - Which variables are outcomes?

# %% [markdown]
# ## 4. Data-quality validation
#
# Before comparing Treatment and Control, validate the data.
#
# ### Minimum checks
#
# - Duplicate experimental units
# - Missing treatment assignments
# - Unexpected treatment labels
# - Inconsistent categorical values
# - Missing outcomes
# - Invalid binary values
# - Date parsing/range
# - Implausible continuous values
#
# ### Your task
#
# Create a reusable quality report and document every cleaning rule.

# %%
# TODO: build a data-quality report
# Suggested output: one compact table or dictionary of issue counts

# %% [markdown]
# ### Cleaning decisions
#
# Document:
# - what you fixed,
# - what you excluded,
# - why,
# - how many rows were affected.
#
# > **Cleaning log:**

# %%
# TODO: create the cleaned analytical dataset as `df`
# Keep the raw dataset unchanged.

# %% [markdown]
# ## 5. Experiment health — Sample Ratio Mismatch (SRM)
#
# The experiment was intended to use a 50/50 Control/Treatment allocation.
#
# ### Your task
#
# 1. Count customers in each group.
# 2. Compare observed counts with the expected 50/50 split.
# 3. Perform an SRM check.
# 4. Explain what you would do if SRM were detected.
#
# Hint: a chi-square goodness-of-fit test can be used as an experiment-health diagnostic.

# %%
# TODO: SRM analysis

# %% [markdown]
# ### Interpretation
#
# > **Does the allocation look healthy? Why?**
# >
# > **If SRM were significant, what would you investigate before continuing?**

# %% [markdown]
# ## 6. Baseline balance
#
# Randomization should make groups comparable in expectation.
#
# ### Your task
#
# Compare important **pre-treatment** characteristics between Control and Treatment:
#
# - country
# - device type
# - customer tenure
# - transaction-value distribution, if you consider it appropriate for this design
#
# Do not mechanically run dozens of significance tests. Focus on practically meaningful imbalance and experiment integrity.

# %%
# TODO: create balance tables / charts

# %% [markdown]
# ### Interpretation
#
# > **Are Control and Treatment reasonably comparable?**
# >
# > **Any imbalance that could threaten interpretation?**

# %% [markdown]
# ## 7. KPI overview
#
# Before formal inference, summarize the experiment.
#
# ### Required metrics
#
# **Primary**
# - checkout completion rate
#
# **Secondary**
# - mean and median checkout time
#
# **Guardrails**
# - payment decline rate
# - support contact rate
# - fraud rate
#
# ### Your task
#
# Create a Control vs Treatment KPI table and at least one useful visualization.

# %%
# TODO: KPI summary table

# %%
# TODO: visualization

# %% [markdown]
# ## 8. Primary KPI — checkout completion
#
# Checkout completion is binary.
#
# ### Your task
#
# Choose and perform an appropriate statistical test.
#
# Report:
#
# - Control rate
# - Treatment rate
# - Absolute lift in percentage points
# - Relative lift
# - Test statistic
# - p-value
# - 95% confidence interval for the absolute difference
# - Whether the result is statistically significant
# - Whether it clears the +2.0 pp business threshold

# %%
# TODO: primary KPI inference

# %% [markdown]
# ### Client-facing interpretation
#
# Explain the result without relying on statistical jargon alone.
#
# > **Interpretation:**

# %% [markdown]
# ## 9. Guardrail analysis
#
# Analyze:
#
# - payment decline rate
# - support contact rate
# - fraud rate
#
# ### Your task
#
# For each guardrail, quantify the difference and uncertainty. Pay special attention to **fraud**, because it is a rare event.
#
# Answer:
# - Is there evidence of harm?
# - Is the size of any movement operationally meaningful?
# - Does any guardrail block rollout?

# %%
# TODO: guardrail tests and summary table

# %% [markdown]
# ### Guardrail recommendation
#
# > **Interpretation:**

# %% [markdown]
# ## 10. Continuous metric — checkout time
#
# Checkout time is intentionally right-skewed.
#
# ### Your task
#
# 1. Inspect the distribution.
# 2. Compare mean and median.
# 3. Quantify skewness/outliers.
# 4. Choose an appropriate inference approach.
# 5. Explain why your test is appropriate.
# 6. Consider a robustness/sensitivity check.

# %%
# TODO: distribution diagnostics and visualization

# %%
# TODO: statistical analysis of checkout time

# %% [markdown]
# ### Interpretation
#
# > **What does the checkout-time result add to the business story?**

# %% [markdown]
# ## 11. Segment analysis
#
# Investigate treatment response by:
#
# - device type
# - country
# - customer tenure
#
# ### Your task
#
# For each segment, compare Control and Treatment completion rates and sample sizes.
#
# Then distinguish:
# - a **pre-specified** segment hypothesis, from
# - a **post-hoc** pattern discovered after seeing the data.
#
# Do not automatically recommend a targeted rollout because one subgroup appears strong.

# %%
# TODO: segment tables and charts

# %% [markdown]
# ### Segment interpretation
#
# > **Which segment pattern is most interesting?**
# >
# > **Would you treat it as confirmatory or exploratory? Why?**
# >
# > **Would you recommend a follow-up experiment?**

# %% [markdown]
# ## 12. Confounders and threats to validity
#
# Even with randomization, list possible reasons an observed treatment effect could be misleading.
#
# Consider:
#
# - tracking failures
# - treatment contamination
# - concurrent campaigns
# - outages
# - different eligibility logic
# - repeated users
# - sample-ratio mismatch
# - post-randomization exclusions
# - seasonality / timing
#
# ### Your answer
#
# > **Top validity risks and how I would check them:**

# %% [markdown]
# ## 13. Business impact
#
# Assume NovaPay processes **1,000,000 eligible checkout attempts per year**.
#
# ### Your task
#
# Using the observed absolute checkout-completion lift, estimate:
#
# - incremental completed checkouts per year
# - how you would extend the estimate into financial value if revenue per completed checkout became available
# - what assumptions you would disclose

# %%
ANNUAL_ELIGIBLE_CHECKOUTS = 1_000_000

# TODO: business impact calculation

# %% [markdown]
# ## 14. Final recommendation
#
# Prepare a short executive recommendation using this structure:
#
# 1. **Decision**
# 2. **Primary evidence**
# 3. **Business magnitude**
# 4. **Guardrails**
# 5. **Uncertainty / caveats**
# 6. **Next step**
#
# Write it as if you were presenting to Product, Risk, and a client executive.

# %% [markdown]
# ### Executive recommendation
#
# > **Decision:**
# >
# > **Evidence:**
# >
# > **Business impact:**
# >
# > **Guardrails:**
# >
# > **Caveats:**
# >
# > **Next step:**

# %% [markdown]
# ## 15. Self-review checklist
#
# Before comparing with the guided solution, confirm that you can answer **yes** to these questions:
#
# - [ ] Did I define the business decision before analyzing results?
# - [ ] Did I define H0/H1 and decision thresholds before inference?
# - [ ] Did I validate data quality before comparing groups?
# - [ ] Did I check experimental allocation/SRM?
# - [ ] Did I distinguish pre-treatment balance from outcome analysis?
# - [ ] Did I choose statistical tests based on metric type?
# - [ ] Did I report effect size and confidence intervals, not only p-values?
# - [ ] Did I separate statistical significance from business significance?
# - [ ] Did I analyze guardrails before recommending rollout?
# - [ ] Did I treat rare-event metrics cautiously?
# - [ ] Did I distinguish confirmatory from exploratory segment findings?
# - [ ] Did I consider threats to causal interpretation?
# - [ ] Did I translate the result into business impact?
# - [ ] Did I make a clear recommendation with caveats and next steps?
#
# When complete, compare your workflow with `guided_ab_test_analysis.ipynb`.
