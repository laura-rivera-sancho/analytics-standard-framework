# %% [markdown]
# # Customer Value & Lifecycle Challenge
# Build an independent, point-in-time customer treatment recommendation from the tracked Harbor & Pine sample.

# %% [markdown]
# ## Tasks
# 1. Write the decision contract and validate the order grain.
# 2. Choose and justify a lookback window.
# 3. Produce RFM scores and auditable segment rules.
# 4. Compare two snapshot dates and distinguish behavior from threshold movement.
# 5. Design a consent-aware audience under a fixed capacity.
# 6. Specify a holdout, outcome, guardrails, and scale decision.

# %%
from pathlib import Path
import pandas as pd
root = Path.cwd().resolve().parents[0] if Path.cwd().name == 'notebooks' else Path.cwd().resolve()
orders = pd.read_csv(root / '06_customer_value_lifecycle/data/raw/harbor_pine_orders_sample.csv')
orders.head()
