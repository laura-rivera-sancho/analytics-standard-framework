# %% [markdown]
# # PayWave Customer Inactivity Prediction — Challenge
#
# Build and defend a capacity-constrained predictive decision system. Complete the TODO cells, document assumptions, and finish with a stakeholder-ready recommendation.

# %% [markdown]
# ## How to use this challenge
#
# Read the business case and data dictionary first. Do not open the answer key or expected results until you have completed your analysis.

# %%
from pathlib import Path
import sys

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

MODULE_ROOT = Path.cwd()
if MODULE_ROOT.name == 'notebooks':
    MODULE_ROOT = MODULE_ROOT.parent
sys.path.insert(0, str(MODULE_ROOT))

from src.generate_synthetic_data import generate_raw_data

# %% [markdown]
# ## 1. Business framing
#
# Document the decision, target, observation window, prediction horizon, eligible population, analytical unit, action, operating capacity, and error trade-offs.

# %% [markdown]
# ### Your answer
#
# TODO

# %% [markdown]
# ## 2. Generate and inspect the raw data

# %%
raw = generate_raw_data()
display(raw.head())
print(raw.shape)

# %% [markdown]
# ## 3. Data quality and leakage
#
# Identify duplicates, missingness, invalid values, unexpected categories, and every field unavailable at scoring time. Document rather than silently applying cleaning rules.

# %%
# TODO: build a data-quality and leakage report

# %%
# TODO: create the cleaned analytical dataset as `df`

# %% [markdown]
# ## 4. Temporal validation
#
# Define Train, Validation, and Test chronologically. Explain why your split represents the intended deployment setting and how repeated customers are handled.

# %%
# TODO: create and summarize chronological splits

# %% [markdown]
# ## 5. Preprocessing and baselines
#
# Create a leakage-safe preprocessing pipeline. Establish the recency business rule and Logistic Regression before evaluating more complex models.

# %%
# TODO: build training-only preprocessing and baseline models

# %% [markdown]
# ## 6. Candidate-model comparison
#
# Compare Logistic Regression, Random Forest, and Gradient Boosting on Validation. Use PR AUC, ROC AUC, calibration where applicable, and capacity metrics.

# %%
# TODO: fit candidates and create a Validation comparison table

# %% [markdown]
# ### Model-selection rationale
#
# TODO: select a candidate using Validation only and discuss performance, calibration, interpretability, stability, and operational complexity.

# %% [markdown]
# ## 7. Final held-out Test evaluation

# %%
# TODO: evaluate the frozen model and business rule on Test

# %% [markdown]
# ## 8. Calibration and operating policy
#
# Assess probability calibration and explain why the 5,000-contact ranked policy is preferable to an arbitrary 0.50 threshold. Do not calculate Brier loss for a raw score outside [0, 1].

# %%
# TODO: create calibration and top-k diagnostics

# %% [markdown]
# ## 9. Segment analysis

# %%
# TODO: evaluate important segments with sample size and prevalence

# %% [markdown]
# ## 10. Business-value sensitivity

# %%
# TODO: estimate conservative, base, and optimistic value scenarios

# %% [markdown]
# ## 11. Risks, monitoring, and governance
#
# TODO: define production feature checks, drift metrics, performance monitoring, segment safeguards, retraining thresholds, ownership, and rollback criteria.

# %% [markdown]
# ## 12. Executive recommendation
#
# TODO: recommend deploy, pilot, iterate, or do not deploy. Lead with the decision and support it with incremental performance, economics, limitations, and next actions.

# %% [markdown]
# ## Self-review checklist
#
# - [ ] No future-information fields enter the model.
# - [ ] Preprocessing is fit on Train only.
# - [ ] Test does not influence model selection.
# - [ ] Ranking and probability metrics are interpreted correctly.
# - [ ] Capacity matches the scoring cycle.
# - [ ] Segment findings include prevalence and sample size.
# - [ ] Value assumptions are explicit.
# - [ ] Predictive performance is not described as causal impact.
