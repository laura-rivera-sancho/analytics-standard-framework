# %% [markdown]
# # Ad Hoc Analysis Challenge — OrbitMart
#
# You have four analyst hours to determine why checkout completion changed and recommend an action. Work independently with the synthetic sample or regenerate the full data. Do not consult the answer key until your memo is complete.

# %% [markdown]
# ## Required deliverables
#
# 1. Intake and decision contract
# 2. Metric definition and matched-period validation
# 3. Raw-to-clean data reconciliation
# 4. KPI tree and prioritized hypothesis map
# 5. Bounded segment diagnostics with denominator and multiplicity controls
# 6. Rate-versus-mix decomposition
# 7. Business-impact estimate
# 8. Facts, supported hypotheses, unknowns, and causal limits
# 9. Immediate action, owner, monitoring, and stopping rule

# %%
from pathlib import Path
import pandas as pd

candidate_roots = [Path.cwd(), Path.cwd().parent, Path.cwd().parents[1]]
module_root = next(root / "05_ad_hoc_analysis" for root in candidate_roots if (root / "05_ad_hoc_analysis").exists())
raw = pd.read_csv(module_root / "data" / "raw" / "orbitmart_checkout_diagnostic_sample.csv")
raw.head()

# %% [markdown]
# ## 1. Write the analysis contract and hypothesis map

# %%
# Define decision, KPI, periods, materiality, dimensions, and stopping rule.
analysis_contract = None
hypothesis_map = None

# %% [markdown]
# ## 2. Validate and reconcile the data
#
# Check grain, freshness, missingness, categories, impossible values, and funnel ordering. Explain each treatment.

# %%
# Your data-quality report and cleaning logic here.
quality_report = None
clean = raw.copy()

# %% [markdown]
# ## 3. Confirm the headline and diagnose the KPI tree
#
# Use summed counts, equal periods, and explicit denominators. Verify the KPI-tree identity.

# %%
# Your period comparison and KPI tree here.
period_summary = None
kpi_tree = None

# %% [markdown]
# ## 4. Run bounded segment diagnostics
#
# Use pre-specified dimensions, minimum denominators, practical thresholds, and false-discovery-rate correction. Preserve all tested branches.

# %%
# Your segment, rate/mix, and multiplicity work here.
segment_results = None

# %% [markdown]
# ## 5. Estimate impact and triangulate
#
# Choose a baseline explicitly, calculate the outcome and value gap, and compare an independent operational signal.

# %%
# Your impact estimate and triangulation here.
impact = None

# %% [markdown]
# ## 6. Write the decision memo
#
# Lead with the action. Separate facts, supported hypotheses, unknowns, and speculation. Name the mitigation owner, rollback criteria, recovery measures, and stopping rule. Use the [scoring rubric](../templates/challenge_scoring_rubric.md) for self-review.
