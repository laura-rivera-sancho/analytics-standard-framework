# %% [markdown]
# # Target Analysis Challenge — LuminaPay
#
# Independently recommend an activation population for a 6,000-contact Instant Settlement campaign. Use the synthetic sample for quick inspection or regenerate the full population. Do not consult the answer key until your readout is complete.

# %% [markdown]
# ## Deliverables
#
# 1. Decision contract and explicit interpretation boundary
# 2. Raw-to-valid population reconciliation
# 3. Ordered eligibility funnel and rule audit
# 4. Eligible segment profile
# 5. Transparent need, value, and fit prioritization
# 6. 3,000, 6,000, and 9,000 capacity comparison
# 7. Coverage and governance review
# 8. Concise recommendation, activation controls, and measurement plan

# %%
from pathlib import Path
import pandas as pd

candidate_roots = [Path.cwd(), Path.cwd().parent, Path.cwd().parents[1]]
module_root = next(root / "03_target_analysis" for root in candidate_roots if (root / "03_target_analysis").exists())
sample_path = module_root / "data" / "raw" / "lumina_settlement_target_sample.csv"
raw = pd.read_csv(sample_path)
raw.head()

# %% [markdown]
# ## 1. Frame and validate
#
# Write the decision contract. Quantify duplicates, missingness, invalid categories, and impossible values. Explain every cleaning choice and reconcile the valid population.

# %%
# Your validation and cleaning work here
quality_report = None
clean = raw.copy()

# %% [markdown]
# ## 2. Define eligibility
#
# Translate each policy statement into a reproducible Boolean rule. Show a denominator-consistent funnel and verify the simultaneous intersection equals the final funnel count.

# %%
# Your eligibility rules and funnel here
eligible = clean.copy()

# %% [markdown]
# ## 3. Prioritize under capacity
#
# Propose an interpretable point system across need, value, and fit. Defend thresholds, specify null behavior, and add a deterministic tie-breaker. Do not score country or industry.

# %%
# Your scoring, tiering, ranking, and 6,000-selection logic here
ranked = eligible.copy()

# %% [markdown]
# ## 4. Size and stress-test the opportunity
#
# Choose explicit tier adoption and contribution assumptions. Compare at least three capacities and explain what is known versus assumed.

# %%
# Your opportunity sizing and sensitivity analysis here
sensitivity = None

# %% [markdown]
# ## 5. Review coverage and safeguards
#
# Profile eligible and selected merchants by operational segments. Investigate unexpected concentration, unknown-data coverage, and policy exceptions without making causal claims.

# %%
# Your segment and safeguard review here
coverage_review = None

# %% [markdown]
# ## 6. Write the decision readout
#
# State whether to activate, which merchants and tiers to include, what assumptions drive value, what approvals and suppressions are required, and how incremental impact will be measured. Use the [scoring rubric](../templates/challenge_scoring_rubric.md) for self-review.
